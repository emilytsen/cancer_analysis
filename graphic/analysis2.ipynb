# %% [markdown]
# # Number of Deaths Over the Years

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/emilytsen/Documents/projects/ds_cancer/df/df_countrys.csv')

# %%
# Rename columns to remove whitespace
data.columns = data.columns.str.strip().str.replace(' ', '_')

# %%
year_min = data['YEAR'].min()
year_max = data['YEAR'].max()
print(f"The data go from year {year_min} to year {year_max}")
# Out:
# The data go from year 1990 to year 2016

# %%
# Filter data to include only relevant columns
stomach_cancer_data = data[['YEAR', 'STOMACH_CANCER']].copy()

# Group by year and sum the number of stomach cancer deaths
stomach_cancer_yearly = stomach_cancer_data.groupby('YEAR')['STOMACH_CANCER'].sum().reset_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(stomach_cancer_yearly['YEAR'], stomach_cancer_yearly['STOMACH_CANCER'], marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths from STOMACH_CANCER Over the Years')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filter data to include only relevant columns
stomach_cancer_data = data[['YEAR', 'PROSTATE_CANCER']].copy()

# Group by year and sum the number of cancer deaths
stomach_cancer_yearly = stomach_cancer_data.groupby('YEAR')['PROSTATE_CANCER'].sum().reset_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(stomach_cancer_yearly['YEAR'], stomach_cancer_yearly['PROSTATE_CANCER'], marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths from PROSTATE_CANCER Over the Years')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filter data to include only relevant columns
stomach_cancer_data = data[['YEAR', 'OVARIAN_CANCER']].copy()

# Group by year and sum the number of cancer deaths
stomach_cancer_yearly = stomach_cancer_data.groupby('YEAR')['OVARIAN_CANCER'].sum().reset_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(stomach_cancer_yearly['YEAR'], stomach_cancer_yearly['OVARIAN_CANCER'], marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths from OVARIAN_CANCER Over the Years')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Filter data to include only relevant columns
stomach_cancer_data = data[['YEAR', 'MALIGNANT_SKIN_MELANOMA']].copy()

# Group by year and sum the number of cancer deaths
stomach_cancer_yearly = stomach_cancer_data.groupby('YEAR')['MALIGNANT_SKIN_MELANOMA'].sum().reset_index()

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(stomach_cancer_yearly['YEAR'], stomach_cancer_yearly['MALIGNANT_SKIN_MELANOMA'], marker='o')
plt.xlabel('Year')
plt.ylabel('Number of Deaths')
plt.title('Number of Deaths from MALIGNANT_SKIN_MELANOMA Over the Years')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
